# %% [markdown]
# # EJERCICIO 3

# %%
from wget import download
from os import path, listdir
import pandas as pd

# %% [markdown]
# ## Implementar en una notebook de Jupyter el código necesario para...

# %% [markdown]
# #### I) Descargar automáticamente ambos archivos :
#
# Descargo el archivo que contiene la descripción del material de trabajo:

# %% [markdown]
# Ahora, descargo el archivo que contiene los datos:

# %%
if not path.exists("catalogo_streaming_argentina_2024.xlsx") :
    download("https://ignaciorlando.github.io/datasets/data-science/catalogo_streaming_argentina_2024.xlsx")
else :
    print("El archivo ya existe")
# Out:
# El archivo ya existe

# %% [markdown]
# #### III) Leer el archivo de datos.
#
# Para el siguiente paso, abro el archivo con la libreria de "Pandas":

# %%
raw_dataframe = pd.read_excel("catalogo_streaming_argentina_2024.xlsx")

raw_dataframe
# Out:
#                      title            platform   type  imdbVotes  imdbScore  \
# 0          Cadena perpetua                 Max  MOVIE  2906253.0        9.3
# 1      El caballero oscuro                 Max  MOVIE  2893241.0        9.0
# 2                   Origen                 Max  MOVIE  2570263.0        8.8
# 3      El club de la lucha         Disney Plus  MOVIE  2345071.0        8.8
# 4      El club de la lucha             Netflix  MOVIE  2345071.0        8.8
# ...                    ...                 ...    ...        ...        ...
# 19812             Три кота             Netflix   SHOW        NaN        NaN
# 19813           أم الدراهم  Amazon Prime Video   SHOW        NaN        NaN
# 19814            ورق مسموم  Amazon Prime Video   SHOW        NaN        NaN
# 19815                 ガクドリ  Amazon Prime Video  MOVIE        NaN        NaN
# 19816           新歌舞伎：赤胴鈴之助             Netflix  MOVIE        NaN        NaN
#
#        tmdbPopularity  tmdbScore  runtime  \
# ...

# %% [markdown]
# #### IV) Imprimir la cabecera del archivo

# %%
raw_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19817 entries, 0 to 19816
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           19817 non-null  object
#  1   platform        19817 non-null  object
#  2   type            19817 non-null  object
#  3   imdbVotes       17854 non-null  float64
#  4   imdbScore       17927 non-null  float64
#  5   tmdbPopularity  19538 non-null  float64
#  6   tmdbScore       18954 non-null  float64
#  7   runtime         19817 non-null  int64
#  8   genres          19665 non-null  object
#  9   director        14626 non-null  object
#  10  year_range      19817 non-null  object
#  11  url             19817 non-null  object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.8+ MB

# %% [markdown]
# #### V) Imprimir los primeros 5 registros del archivo.

# %%
raw_dataframe.head()
# Out:
#                  title     platform   type  imdbVotes  imdbScore  \
# 0      Cadena perpetua          Max  MOVIE  2906253.0        9.3
# 1  El caballero oscuro          Max  MOVIE  2893241.0        9.0
# 2               Origen          Max  MOVIE  2570263.0        8.8
# 3  El club de la lucha  Disney Plus  MOVIE  2345071.0        8.8
# 4  El club de la lucha      Netflix  MOVIE  2345071.0        8.8
#
#    tmdbPopularity  tmdbScore  runtime  \
# 0         159.594      8.705      142
# 1         111.674      8.516      152
# 2         139.644      8.369      148
# 3         108.297      8.400      139
# 4         108.297      8.400      139
#
#                                               genres           director  \
# 0                                      Drama, Crimen     Frank Darabont
# 1  Misterio & Suspense, Drama, Acción & Aventura,...  Christopher Nolan
# 2  Ciencia ficción, Acción & Aventura, Misterio &...  Christopher Nolan
# ...

# %% [markdown]
# #### VI) Imprimir el resumen estadístico del mismo

# %%
raw_dataframe.describe(include="all")
# Out:
#             title platform   type     imdbVotes     imdbScore  tmdbPopularity  \
# count       19817    19817  19817  1.785400e+04  17927.000000    19538.000000
# unique      18008        6      2           NaN           NaN             NaN
# top     La niñera  Netflix  MOVIE           NaN           NaN             NaN
# freq            5     7109  14060           NaN           NaN             NaN
# mean          NaN      NaN    NaN  4.838858e+04      6.399520       41.195589
# std           NaN      NaN    NaN  1.488473e+05      1.200258      131.031366
# min           NaN      NaN    NaN  5.000000e+00      1.100000        0.001000
# 25%           NaN      NaN    NaN  4.620000e+02      5.700000        5.433250
# 50%           NaN      NaN    NaN  2.849500e+03      6.500000       14.428500
# 75%           NaN      NaN    NaN  2.196975e+04      7.300000       33.312500
# max           NaN      NaN    NaN  2.906253e+06      9.700000     4173.518000
#
# ...

# %% [markdown]
# ## Analizar los valores de las columnas. ¿Qué tipo de datos hay en cada una? ¿Qué representan? Incluir información del análisis en la notebook.
#
# - **TITLE:** dato cualitativo nominal. Guarda el titulo de la pelicula o serie, puede servir para saber qué títulos son llamativos o conocidos.
# - **PLATFORM:** dato cualitativo nominal. Se refiere a la plataforma de streaming donde se encuentra la serie o pelicula, lo que puede ser útil para ver el rendimiento de las plataformas.
# - **TYPE:** dato cualitativo nominal. Representa el tipo de producto: si es una pelicula o serie.
# - **IMDBVOTES:** dato cuantitativo discreto. Se refiere a la gente que votó en IMDB.
# - **IMDBSCORE:** dato cuantitativo continuo. Indica el puntaje del filme en IMDb.
# - **TMDBPOPULARITY:** dato cuantitativo continuo. Muestra un índice de popularidad.
# - **TMDBSCORE:** dato cuantitativo continuo. Indica el puntaje de la película en TMDb.
# - **RUNTIME:** dato cuantitativo discreto. Se refiere a la duración del producto.
# - **GENRES:** dato cualitativo nominal. Indica el género de la obra.
# - **DIRECTOR:** dato cuantitativo nominal. El director podría indicarnos tendencias de la gente.
# - **YEAR_RANGE:** dato cualitativo ordinal. Puede referirse al rango de años en los cuales está ambientado el producto.
# - **URL:** dato cualitativo nominal.

# %% [markdown]
# ## Proponer una serie de análisis propios:

# %% [markdown]
# #### I) ¿Cuántos directores distintos hay?

# %%
frecuencia_directores = raw_dataframe["director"].value_counts() 

num_directores = frecuencia_directores.shape[0]
print(f"La cantidad de directores: {num_directores}\n")
print(f"Los directores en orden según la cantidad de veces que aparecen:\n\n{frecuencia_directores}\n")
# Out:
# La cantidad de directores: 8812
#
# Los directores en orden según la cantidad de veces que aparecen:
#
# director
# Steven Spielberg    27
# Woody Allen         24
# Pedro Almodóvar     21
# Michael Bay         21
# Robert Vince        19
#                     ..
# Anthony Burns        1
# Jee Hye-won          1
# René Cardona III     1
# Tobi Baumann         1
# Hideaki Takizawa     1
# Name: count, Length: 8812, dtype: int64

# %% [markdown]
# #### II) ¿Quién es el director con más películas?

# %%
director_repetido = raw_dataframe["director"].mode()[0] 
print(f"El director más repetido es: {director_repetido}")
# Out:
# El director más repetido es: Steven Spielberg

# %% [markdown]
# #### III) ¿Cuántas series hay? ¿Y cuántos programas de TV?

# %%
cant_programas = raw_dataframe[raw_dataframe["type"] == "TV Show"].shape[0]
print(f"La cantidad de programas es: {cant_programas}")

cant_series = raw_dataframe[raw_dataframe["listed_in"].str.contains("series", case=False)].shape[0]
print(f"La cantidad de series es: {cant_series}")
# Out:
# La cantidad de programas es: 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Compumar\Documents\Programación\Python\Fundamentos Ciencia de Datos\Práctico 2\entorno\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'listed_in'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# #### IV) ¿Cuál es la película más vieja del catálogo? ¿Y la serie?

# %%
fecha_mas_vieja = raw_dataframe["release_year"].min()
peliculas_mas_viejas = raw_dataframe[raw_dataframe["release_year"] == fecha_mas_vieja]
peliculas_mas_viejas
# Out:
#      show_id     type                              title director cast  \
# 4250   s4251  TV Show  Pioneers: First Women Filmmakers*      NaN  NaN
#
#      country         date_added  release_year rating  duration listed_in  \
# 4250     NaN  December 30, 2018          1925  TV-14  1 Season  TV Shows
#
#                                             description  Unnamed: 12  \
# 4250  This collection restores films from women who ...          NaN
#
#       Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  \
# 4250          NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# 4250          NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 23  Unnamed: 24  Unnamed: 25
# 4250          NaN          NaN          NaN

# %% [markdown]
# #### V) Dado un país, determinar cuántas películas de ese país hay en la base de datos

# %%
pais = input("Ingrese un país:")
cant_pais = raw_dataframe[raw_dataframe["country"].str.casefold() == pais.casefold()].shape[0]
print(f"El país que elegiste aparece {cant_pais} veces")
# Out:
# Ingrese un país: United States
# El país que elegiste aparece 2819 veces
